# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/TimeGender.csv')
df
# Out:
#            date  time     sex  confirmed  deceased
# 0    2020-03-02     0    male       1591        13
# 1    2020-03-02     0  female       2621         9
# 2    2020-03-03     0    male       1810        16
# 3    2020-03-03     0  female       3002        12
# 4    2020-03-04     0    male       1996        20
# ..          ...   ...     ...        ...       ...
# 237  2020-06-28     0  female       7265       131
# 238  2020-06-29     0    male       5470       151
# 239  2020-06-29     0  female       7287       131
# 240  2020-06-30     0    male       5495       151
# 241  2020-06-30     0  female       7305       131
#
# [242 rows x 5 columns]

# %%
df_sel = df[['date', 'sex', 'confirmed']]
df_sel
# Out:
#            date     sex  confirmed
# 0    2020-03-02    male       1591
# 1    2020-03-02  female       2621
# 2    2020-03-03    male       1810
# 3    2020-03-03  female       3002
# 4    2020-03-04    male       1996
# ..          ...     ...        ...
# 237  2020-06-28  female       7265
# 238  2020-06-29    male       5470
# 239  2020-06-29  female       7287
# 240  2020-06-30    male       5495
# 241  2020-06-30  female       7305
#
# [242 rows x 3 columns]

# %%
df_male = df_sel['sex'] == 'male'
male = df_sel[df_male]
male
# Out:
#            date   sex  confirmed
# 0    2020-03-02  male       1591
# 2    2020-03-03  male       1810
# 4    2020-03-04  male       1996
# 6    2020-03-05  male       2149
# 8    2020-03-06  male       2345
# ..          ...   ...        ...
# 232  2020-06-26  male       5384
# 234  2020-06-27  male       5412
# 236  2020-06-28  male       5450
# 238  2020-06-29  male       5470
# 240  2020-06-30  male       5495
#
# [121 rows x 3 columns]

# %%
df_female = df_sel['sex'] == 'female'
female = df_sel[df_female]
female
# Out:
#            date     sex  confirmed
# 1    2020-03-02  female       2621
# 3    2020-03-03  female       3002
# 5    2020-03-04  female       3332
# 7    2020-03-05  female       3617
# 9    2020-03-06  female       3939
# ..          ...     ...        ...
# 233  2020-06-26  female       7218
# 235  2020-06-27  female       7241
# 237  2020-06-28  female       7265
# 239  2020-06-29  female       7287
# 241  2020-06-30  female       7305
#
# [121 rows x 3 columns]

# %%
plt.figure(figsize=(10, 8))

sns.barplot(data=male, x='confirmed', y='date')
# sns.barplot(data=female, x='comfirmed' y='date')
