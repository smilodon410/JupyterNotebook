# %%
import pandas as pd

# %%
df = pd.read_csv('data/부산광역시 금정구 모범음식점 현황_20200828.csv', encoding='cp949')
df
# Out:
#     연번              업소명                                        소재지(도로명)  \
# 0    1        거창맷돌(부곡점)                         부산광역시 금정구 부곡로 158 (부곡동)
# 1    2              경희궁                         부산광역시 금정구 금샘로 441 (구서동)
# 2    3               금성                         부산광역시 금정구 산성로 443 (금성동)
# 3    4            김가네국수                         부산광역시 금정구 금강로 686 (남산동)
# 4    5             낙원식당                     부산광역시 금정구 식물원로44번길 12 (장전동)
# 5    6          남산찹쌀아구찜                         부산광역시 금정구 금강로 694 (남산동)
# 6    7          누리마을감자탕                   부산광역시 금정구 중앙대로1719번길 61 (부곡동)
# 7    8               느루                         부산광역시 금정구 금샘로 478 (남산동)
# 8    9              늘아침                   부산광역시 금정구 부산대학로64번길 155 (장전동)
# 9   10               다루                         부산광역시 금정구 금샘로 375 (구서동)
# 10  11             대성갈비                         부산광역시 금정구 금강로 630 (남산동)
# 11  12              대성관                         부산광역시 금정구 금강로 179 (장전동)
# ...
