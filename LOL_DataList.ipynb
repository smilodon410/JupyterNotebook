# %%
import pandas as pd

# %%
item = pd.read_csv('riot_item.csv')
item
# Out:
#      Unnamed: 0  item_id               name  \
# 0             0     1001     Boots of Speed
# 1             0     1004       Faerie Charm
# 2             0     1006  Rejuvenation Bead
# 3             0     1011       Giant's Belt
# 4             0     1018   Cloak of Agility
# ..          ...      ...                ...
# 238           0     3902   Death's Daughter
# 239           0     3903       Raise Morale
# 240           0     3905       Twin Shadows
# 241           0     3907        Spellbinder
# 242           0     3916       Oblivion Orb
#
#                                             upper_item  \
# 0    ['3006', '3047', '3020', '3158', '3111', '3117...
# 1                     ['3028', '3070', '3073', '3114']
# 2                             ['3077', '3801', '3194']
# 3             ['3083', '3084', '3022', '3143', '3742']
# 4                     ['3086', '3095', '3031', '3508']
# ..                                                 ...
# ...

# %%
item[['key', 'name']] = item[['item_id','name']]
item
# Out:
#      Unnamed: 0  item_id               name  \
# 0             0     1001     Boots of Speed
# 1             0     1004       Faerie Charm
# 2             0     1006  Rejuvenation Bead
# 3             0     1011       Giant's Belt
# 4             0     1018   Cloak of Agility
# ..          ...      ...                ...
# 238           0     3902   Death's Daughter
# 239           0     3903       Raise Morale
# 240           0     3905       Twin Shadows
# 241           0     3907        Spellbinder
# 242           0     3916       Oblivion Orb
#
#                                             upper_item  \
# 0    ['3006', '3047', '3020', '3158', '3111', '3117...
# 1                     ['3028', '3070', '3073', '3114']
# 2                             ['3077', '3801', '3194']
# 3             ['3083', '3084', '3022', '3143', '3742']
# 4                     ['3086', '3095', '3031', '3508']
# ..                                                 ...
# ...

# %%
item = item[['key', 'name']]
item
# Out:
#       key               name
# 0    1001     Boots of Speed
# 1    1004       Faerie Charm
# 2    1006  Rejuvenation Bead
# 3    1011       Giant's Belt
# 4    1018   Cloak of Agility
# ..    ...                ...
# 238  3902   Death's Daughter
# 239  3903       Raise Morale
# 240  3905       Twin Shadows
# 241  3907        Spellbinder
# 242  3916       Oblivion Orb
#
# [243 rows x 2 columns]

# %%
item.to_csv("riot_item.csv")
