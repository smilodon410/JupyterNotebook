# %%
# %pwd
# Out:
# 'C:\\Users\\BIT_R45\\JupyterNotebook\\eduwith - pandas'

# %%
# !move "C:\Users\BIT_R45\Downloads\도로교통공단_교통사고 다발지역_20201104.csv" .
# Out:
# 지정된 파일을 찾을 수 없습니다.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: D09F-FB40
#
#  C:\Users\BIT_R45\JupyterNotebook\eduwith - pandas 디렉터리
#
# 2020-11-18  오후 08:22    <DIR>          .
# 2020-11-18  오후 08:22    <DIR>          ..
# 2020-11-18  오후 07:56    <DIR>          .ipynb_checkpoints
# 2020-11-18  오후 07:53            64,489 Basic Pandas.ipynb
# 2020-11-18  오후 08:22            17,451 File-Path-Setting.ipynb
# 2020-11-18  오전 09:10           156,961 Jupyter Basic.ipynb
# 2020-11-18  오후 07:58        11,939,761 도로교통공단_교통사고 다발지역_20201104.csv
#                4개 파일          12,178,662 바이트
#                3개 디렉터리  64,453,881,856 바이트 남음

# %%
import pandas as pd

# %%
pd.read_csv("도로교통공단_교통사고 다발지역_20201104.csv", encoding='cp949')
# Out:
#        사고지역관리번호  사고연도  사고유형구분      위치코드    사고다발지역시도시군구  \
# 0       2013060  2012  스쿨존어린이  11110001     서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이  11290001     서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이  11290002     서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이  11290003     서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이  11320001     서울특별시 도봉구1
# ...         ...   ...     ...       ...            ...
# 11375   2020037  2019     자전거  48129001  경상남도 창원시 진해구1
# 11376   2020037  2019     자전거  48170001      경상남도 진주시1
# 11377   2020037  2019     자전거  48240001      경상남도 사천시1
# 11378   2020037  2019     자전거  48250001      경상남도 김해시1
# 11379   2020037  2019     자전거  48250002      경상남도 김해시2
#
#                           사고지역위치명  사고건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0          서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1       0
# 1          서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1       1
# 2       서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0       0
# ...
